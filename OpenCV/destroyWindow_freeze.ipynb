# %% [markdown]
# - https://supership.slack.com/archives/CK519TCEN/p1564545356017800
# - https://teratail.com/questions/107002
# - https://stackoverflow.com/questions/13734276/python-freezes-after-cv2-destroywindowhttps://github.com/opencv/opencv/blob/dd259503c1fbf570d38e2f0a76a77e3919b0ebbd/modules/highgui/src/window_QT.cpp#L548

# %%
# !pip install opencv-python

# %%
import time
import cv2 as cv
cv.__version__
# Out:
# '4.1.0'

# %%
FILE_NAME = "sky.jpg"
WINDOW_NAME = "win"

image = cv.imread(FILE_NAME)
cv.namedWindow(WINDOW_NAME)

# %%
cv.imshow(WINDOW_NAME, image)
cv.waitKey(1000)
# Out:
# -1

# %%
cv.waitKey(5000)
cv.destroyWindow(WINDOW_NAME)
#cv.destroyAllWindows()
cv.waitKey(5000)
# Out:
# -1

# %% [markdown]
# - https://teratail.com/questions/183659

# %%
import cv2 as cv
from IPython.display import Image
img = cv.imread('sky.jpg')
eimg = cv.imencode('.png', img)[1]
Image(eimg)
